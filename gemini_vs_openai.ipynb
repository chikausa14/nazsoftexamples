# %% [markdown]
# # Comparison of OpenAI

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

chat_model = ChatOpenAI(model="gpt-4", openai_api_key=api_key)

result = chat_model.invoke("can you generate me php code for a tennis club registration form")
print(result.content)
# Out:
# Sure, below is a simple PHP code for a tennis club registration form. Please note that this form is a basic example and it does not include form validation, error handling, or database connection. These should be implemented appropriately based on your specific needs.
#
# ```php
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Tennis Club Registration Form</h2>
#
# <form action="submit_form.php" method="post">
#   <label for="fname">First Name:</label><br>
#   <input type="text" id="fname" name="fname"><br>
#   <label for="lname">Last Name:</label><br>
#   <input type="text" id="lname" name="lname"><br>
#   <label for="email">Email:</label><br>
#   <input type="email" id="email" name="email"><br>
#   <label for="phone">Phone:</label><br>
#   <input type="tel" id="phone" name="phone"><br>
#   <input type="submit" value="Submit">
# </form>
#
# </body>
# </html>
# ```
#
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

chat_model = ChatGoogleGenerativeAI(model="gemini-pro", google_api_key=api_key)

result = chat_model.invoke("can you generate me php code for a tennis club registration form")
print(result.content)
# Out:
# ```php
# <?php
#
# class TennisClub {
#
#     private $name;
#     private $address;
#     private $phone;
#     private $email;
#     private $members;
#     private $courts;
#
#     public function __construct($name, $address, $phone, $email) {
#         $this->name = $name;
#         $this->address = $address;
#         $this->phone = $phone;
#         $this->email = $email;
#         $this->members = array();
#         $this->courts = array();
#     }
#
#     public function getName() {
#         return $this->name;
#     }
#
#     public function getAddress() {
#         return $this->address;
#     }
#
#     public function getPhone() {
#         return $this->phone;
#     }
#
#     public function getEmail() {
#         return $this->email;
#     }
#
#     public function getMembers() {
#         return $this->members;
#     }
#
#     public function addMember($member) {
#         $this->members[] = $member;
#     }
#
#     public function getCourts() {
# ...
